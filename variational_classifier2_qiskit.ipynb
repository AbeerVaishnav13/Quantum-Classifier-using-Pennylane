# %% [markdown]
# # Iris Classification

# %% [markdown]
# ## Quantum and Classical Nodes

# %%
import pennylane as qml
from pennylane import numpy as np
from pennylane.optimize import NesterovMomentumOptimizer

import qiskit
from qiskit.providers.aer.noise import NoiseModel
from qiskit import IBMQ

IBMQ.load_account()
# Out:
# WARNING:qiskit.providers.ibmq.ibmqfactory:Credentials are already in use. The existing account in the session will be replaced.
# <AccountProvider for IBMQ(hub='ibm-q', group='open', project='main')>

# %%
provider = IBMQ.get_provider(hub='ibm-q', group='open')
device = provider.get_backend('ibmq_ourense')
noise_model = NoiseModel.from_backend(device.properties())

dev = qml.device('qiskit.aer', backend='qasm_simulator', wires=2, noise_model=noise_model)

# %%
def get_angles(x):
    beta0 = 2 * np.arcsin(np.sqrt(x[1] ** 2) / np.sqrt(x[0] ** 2 + x[1] ** 2 + 1e-12))
    beta1 = 2 * np.arcsin(np.sqrt(x[3] ** 2) / np.sqrt(x[2] ** 2 + x[3] ** 2 + 1e-12))
    beta2 = 2 * np.arcsin(np.sqrt(x[2] ** 2 + x[3] ** 2) / np.sqrt(x[0] ** 2 + x[1] ** 2 + x[2] ** 2 + x[3] ** 2))
    
    return np.array([beta2, -beta1/2, beta1/2, -beta0/2, beta0/2])

# %%
def stateSeparation(a):
    qml.RY(a[0], wires=0)
    qml.CNOT(wires=[0, 1])
    
    qml.RY(a[1], wires=1)
    qml.CNOT(wires=[0, 1])
    
    qml.RY(a[2], wires=1)
    
    qml.PauliX(wires=0)
    qml.CNOT(wires=[0, 1])
    qml.RY(a[3], wires=1)
    qml.CNOT(wires=[0, 1])
    qml.RY(a[4], wires=1)
    qml.PauliX(wires=0)

# %% [markdown]
# ### Test encoding of classical data in quantum circuit

# %%
x = np.array([0.53896774, 0.79503606, 0.27826503, 0.0])
ang = get_angles(x)

@qml.qnode(dev)
def test(angles=None):
    stateSeparation(angles)
    return qml.expval(qml.PauliZ(0))

test(angles=ang)

print("x               : ", x)
print("angles          : ", ang)
print("amplitude vector: ", np.real(dev._state))
# Out:
# x               :  [0.53896774 0.79503606 0.27826503 0.        ]
# angles          :  [ 0.56397465 -0.          0.         -0.97504604  0.97504604]
# amplitude vector:  None

# %%
def layer(W):
    qml.Rot(W[0, 0], W[0, 1], W[0, 2], wires=0)
    qml.Rot(W[1, 0], W[1, 1], W[1, 2], wires=1)
    qml.CNOT(wires=[0, 1])

# %%
@qml.qnode(dev)
def circuit(weights, angles=None):
    stateSeparation(angles)
    
    for W in weights:
        layer(W)
        
    return qml.expval(qml.PauliZ(0))

################################################################################################
def square_loss(labels, predictions):
    loss = 0
    for l, p in zip(labels, predictions):
        loss += ((l - p)**2)
        
    loss /= len(labels)
    return loss

################################################################################################
def accuracy(labels, predictions):
    loss = 0
    for l, p in zip(labels, predictions):
        if abs(l - p) < 1e-5:
            loss += 1
            
    loss /= len(labels)
    return loss

################################################################################################
def variational_classifier(var, angles=None):
    weights = var[0]
    bias = var[1]
    return circuit(weights, angles=angles) + bias

################################################################################################
def cost(weights, features, labels):
    predictions = [variational_classifier(weights, angles=f) for f in features]
    return square_loss(labels, predictions)

# %% [markdown]
# ## Loading Data

# %%
data = np.loadtxt('iris.txt')
X = data[:, 0:2]
print("First X sample (original)  :", X[0])

# pad the vectors to size 2^2 with constant values
padding = 0.3 * np.ones((len(X), 1))
X_pad = np.c_[np.c_[X, padding], np.zeros((len(X), 1))]
print("First X sample (padded)    :", X_pad[0])

# normalize each input
normalization = np.sqrt(np.sum(X_pad ** 2, -1))
X_norm = (X_pad.T / normalization).T
print("First X sample (normalized):", X_norm[0])

# angles for state preparation are new features
features = np.array([get_angles(x) for x in X_norm])
print("First features sample      :", features[0])

Y = data[:, -1]
# Out:
# First X sample (original)  : [0.4  0.75]
# First X sample (padded)    : [0.4  0.75 0.3  0.  ]
# First X sample (normalized): [0.44376016 0.83205029 0.33282012 0.        ]
# First features sample      : [ 0.67858523 -0.          0.         -1.080839    1.080839  ]

# %%
import matplotlib.pyplot as plt
from matplotlib import style

style.use('bmh')
style.use('dark_background')

plt.figure()
plt.scatter(X[:, 0][Y == 1], X[:, 1][Y == 1], c="b", marker="o", edgecolors="k")
plt.scatter(X[:, 0][Y == -1], X[:, 1][Y == -1], c="r", marker="o", edgecolors="k")
plt.title("Original data")
plt.show()

plt.figure()
dim1 = 0
dim2 = 1
plt.scatter(X_norm[:, dim1][Y == 1], X_norm[:, dim2][Y == 1], c="b", marker="o", edgecolors="k")
plt.scatter(X_norm[:, dim1][Y == -1], X_norm[:, dim2][Y == -1], c="r", marker="o", edgecolors="k")
plt.title("Padded and normalised data (dims {} and {})".format(dim1, dim2))
plt.show()

plt.figure()
dim1 = 0
dim2 = 3
plt.scatter(features[:, dim1][Y == 1], features[:, dim2][Y == 1], c="b", marker="o", edgecolors="k")
plt.scatter(
    features[:, dim1][Y == -1], features[:, dim2][Y == -1], c="r", marker="o", edgecolors="k"
)
plt.title("Feature vectors (dims {} and {})".format(dim1, dim2))
plt.show()

# %%
np.random.seed(0)
num_data = len(Y)
num_train = int(0.75 * num_data)
index = np.random.permutation(range(num_data))

feats_train = features[index[:num_train]]
Y_train = Y[index[:num_train]]

feats_val = features[index[num_train:]]
Y_val = Y[index[num_train:]]

X_train = X[index[:num_train]]
X_val = X[index[num_train:]]

# %% [markdown]
# ## Optimization
# First we initialize the variables

# %%
num_qubits = 2
num_layers = 6
var_init = (0.01 * np.random.randn(num_layers, num_qubits, 3), 0.03)

# %% [markdown]
# Again we optimize the cost

# %%
opt = NesterovMomentumOptimizer(0.01)
batch_size = 5

# train the variational classifier
var = var_init
for it in range(100):
    # Update the weights by one optimizer step
    batch_index = np.random.randint(0, num_train, (batch_size,))
    feats_train_batch = feats_train[batch_index]
    Y_train_batch = Y_train[batch_index]
    var = opt.step(lambda v: cost(v, feats_train_batch, Y_train_batch), var)
    
    # Compute predictions on train and validation set
    predictions_train = [np.sign(variational_classifier(var, angles=f)) for f in feats_train]
    predictions_val = [np.sign(variational_classifier(var, angles=f)) for f in feats_val]
    
    # Compute accuracy on train and validation set
    acc_train = accuracy(Y_train, predictions_train)
    acc_val = accuracy(Y_val, predictions_val)
    
    print(
        "Iter: {:5d} | Cost: {:0.7f} | Acc train: {:0.7f} | Acc validation: {:0.7f} "
        "".format(it + 1, cost(var, features, Y), acc_train, acc_val)
    )
# Out:
# Iter:     1 | Cost: 1.4754807 | Acc train: 0.4933333 | Acc validation: 0.5600000
# Iter:     2 | Cost: 1.3654269 | Acc train: 0.4933333 | Acc validation: 0.5600000
# Iter:     3 | Cost: 1.1981797 | Acc train: 0.4800000 | Acc validation: 0.5600000
# Iter:     4 | Cost: 1.0317049 | Acc train: 0.4533333 | Acc validation: 0.5600000
# Iter:     5 | Cost: 0.9211016 | Acc train: 0.5466667 | Acc validation: 0.7600000
# Iter:     6 | Cost: 0.8717365 | Acc train: 0.7066667 | Acc validation: 0.7200000
# Iter:     7 | Cost: 0.8554321 | Acc train: 0.7066667 | Acc validation: 0.7200000
# Iter:     8 | Cost: 0.8445516 | Acc train: 0.7733333 | Acc validation: 0.7200000
# Iter:     9 | Cost: 0.8125704 | Acc train: 0.7333333 | Acc validation: 0.6800000
# Iter:    10 | Cost: 0.8055628 | Acc train: 0.7733333 | Acc validation: 0.7600000
# Iter:    11 | Cost: 0.7780168 | Acc train: 0.8266667 | Acc validation: 0.8800000
# Iter:    12 | Cost: 0.7768808 | Acc train: 0.7466667 | Acc validation: 0.7600000
# Iter:    13 | Cost: 0.7879094 | Acc train: 0.6666667 | Acc validation: 0.7200000
# Iter:    14 | Cost: 0.8202735 | Acc train: 0.6266667 | Acc validation: 0.6400000
# Iter:    15 | Cost: 0.8363396 | Acc train: 0.5733333 | Acc validation: 0.6400000
# Iter:    16 | Cost: 0.8489635 | Acc train: 0.6266667 | Acc validation: 0.6000000
# Iter:    17 | Cost: 0.8329175 | Acc train: 0.6133333 | Acc validation: 0.6400000
# Iter:    18 | Cost: 0.8043184 | Acc train: 0.6533333 | Acc validation: 0.6800000
# Iter:    19 | Cost: 0.7715681 | Acc train: 0.6800000 | Acc validation: 0.7200000
# Iter:    20 | Cost: 0.7545012 | Acc train: 0.7333333 | Acc validation: 0.8000000
# Iter:    21 | Cost: 0.7306422 | Acc train: 0.8400000 | Acc validation: 1.0000000
# Iter:    22 | Cost: 0.7449229 | Acc train: 0.8400000 | Acc validation: 0.9200000
# Iter:    23 | Cost: 0.7547242 | Acc train: 0.7600000 | Acc validation: 0.6800000
# Iter:    24 | Cost: 0.7656451 | Acc train: 0.5866667 | Acc validation: 0.6000000
# Iter:    25 | Cost: 0.7505304 | Acc train: 0.7066667 | Acc validation: 0.6800000
# Iter:    26 | Cost: 0.7648982 | Acc train: 0.7066667 | Acc validation: 0.6400000
# Iter:    27 | Cost: 0.7507854 | Acc train: 0.6000000 | Acc validation: 0.6800000
# Iter:    28 | Cost: 0.7769232 | Acc train: 0.5466667 | Acc validation: 0.5200000
# Iter:    29 | Cost: 0.7758396 | Acc train: 0.5466667 | Acc validation: 0.5200000
# Iter:    30 | Cost: 0.7707959 | Acc train: 0.5600000 | Acc validation: 0.4800000
# Iter:    31 | Cost: 0.7594172 | Acc train: 0.6266667 | Acc validation: 0.4800000
# Iter:    32 | Cost: 0.7445355 | Acc train: 0.7466667 | Acc validation: 0.6800000
# Iter:    33 | Cost: 0.7253579 | Acc train: 0.8666667 | Acc validation: 0.8000000
# Iter:    34 | Cost: 0.7115925 | Acc train: 0.8133333 | Acc validation: 0.7600000
# Iter:    35 | Cost: 0.7255576 | Acc train: 0.8266667 | Acc validation: 0.6800000
# Iter:    36 | Cost: 0.7394132 | Acc train: 0.6000000 | Acc validation: 0.6400000
# Iter:    37 | Cost: 0.7266527 | Acc train: 0.7333333 | Acc validation: 0.7200000
# Iter:    38 | Cost: 0.7264354 | Acc train: 0.7333333 | Acc validation: 0.6800000
# Iter:    39 | Cost: 0.7078194 | Acc train: 0.6533333 | Acc validation: 0.7200000
# Iter:    40 | Cost: 0.7328504 | Acc train: 0.6000000 | Acc validation: 0.6000000
# Iter:    41 | Cost: 0.7238958 | Acc train: 0.6666667 | Acc validation: 0.6800000
# Iter:    42 | Cost: 0.6886649 | Acc train: 0.8000000 | Acc validation: 0.7600000
# Iter:    43 | Cost: 0.6772535 | Acc train: 0.8400000 | Acc validation: 0.7600000
# Iter:    44 | Cost: 0.6697253 | Acc train: 0.8266667 | Acc validation: 0.8000000
# Iter:    45 | Cost: 0.6577769 | Acc train: 0.8533333 | Acc validation: 0.8800000
# Iter:    46 | Cost: 0.6374074 | Acc train: 0.8800000 | Acc validation: 0.8400000
# Iter:    47 | Cost: 0.6313122 | Acc train: 0.8800000 | Acc validation: 0.8800000
# Iter:    48 | Cost: 0.6085418 | Acc train: 0.9066667 | Acc validation: 0.8400000
# Iter:    49 | Cost: 0.6005937 | Acc train: 0.9200000 | Acc validation: 0.9600000
# Iter:    50 | Cost: 0.5992564 | Acc train: 0.9066667 | Acc validation: 0.8800000
# Iter:    51 | Cost: 0.5804223 | Acc train: 0.9066667 | Acc validation: 0.9600000
# Iter:    52 | Cost: 0.5580930 | Acc train: 0.9600000 | Acc validation: 1.0000000
# Iter:    53 | Cost: 0.5494262 | Acc train: 0.9866667 | Acc validation: 0.9600000
# Iter:    54 | Cost: 0.5479950 | Acc train: 0.9466667 | Acc validation: 0.9200000
# Iter:    55 | Cost: 0.5617765 | Acc train: 0.8666667 | Acc validation: 0.9200000
# Iter:    56 | Cost: 0.5695069 | Acc train: 0.8533333 | Acc validation: 0.9200000
# Iter:    57 | Cost: 0.5493096 | Acc train: 0.8400000 | Acc validation: 0.9200000
# Iter:    58 | Cost: 0.5054872 | Acc train: 0.9733333 | Acc validation: 0.9600000
# Iter:    59 | Cost: 0.4814204 | Acc train: 1.0000000 | Acc validation: 1.0000000
# Iter:    60 | Cost: 0.4652134 | Acc train: 0.9733333 | Acc validation: 1.0000000
# Iter:    61 | Cost: 0.4647191 | Acc train: 0.9600000 | Acc validation: 0.9600000
# Iter:    62 | Cost: 0.4781303 | Acc train: 0.9066667 | Acc validation: 0.8800000
# Iter:    63 | Cost: 0.4903877 | Acc train: 0.8666667 | Acc validation: 0.8400000
# Iter:    64 | Cost: 0.4872511 | Acc train: 0.8800000 | Acc validation: 0.8400000
# Iter:    65 | Cost: 0.4626119 | Acc train: 0.9066667 | Acc validation: 0.8400000
# Iter:    66 | Cost: 0.4284505 | Acc train: 0.9466667 | Acc validation: 0.8800000
# Iter:    67 | Cost: 0.3908122 | Acc train: 0.9733333 | Acc validation: 0.9600000
# Iter:    68 | Cost: 0.3607082 | Acc train: 1.0000000 | Acc validation: 1.0000000
# Iter:    69 | Cost: 0.3574898 | Acc train: 1.0000000 | Acc validation: 1.0000000
# Iter:    70 | Cost: 0.3493798 | Acc train: 1.0000000 | Acc validation: 1.0000000
# Iter:    71 | Cost: 0.3356827 | Acc train: 1.0000000 | Acc validation: 1.0000000
# Iter:    72 | Cost: 0.3355440 | Acc train: 1.0000000 | Acc validation: 1.0000000
# Iter:    73 | Cost: 0.3305810 | Acc train: 1.0000000 | Acc validation: 1.0000000
# Iter:    74 | Cost: 0.3192381 | Acc train: 1.0000000 | Acc validation: 1.0000000
# Iter:    75 | Cost: 0.3202015 | Acc train: 1.0000000 | Acc validation: 1.0000000
# Iter:    76 | Cost: 0.3096080 | Acc train: 1.0000000 | Acc validation: 1.0000000
# Iter:    77 | Cost: 0.3091958 | Acc train: 1.0000000 | Acc validation: 1.0000000
# Iter:    78 | Cost: 0.2981407 | Acc train: 1.0000000 | Acc validation: 1.0000000
# Iter:    79 | Cost: 0.2984489 | Acc train: 1.0000000 | Acc validation: 1.0000000
# Iter:    80 | Cost: 0.2883901 | Acc train: 1.0000000 | Acc validation: 1.0000000
# Iter:    81 | Cost: 0.2890575 | Acc train: 0.9866667 | Acc validation: 1.0000000
# Iter:    82 | Cost: 0.2905102 | Acc train: 1.0000000 | Acc validation: 1.0000000
# Iter:    83 | Cost: 0.2779419 | Acc train: 1.0000000 | Acc validation: 1.0000000
# Iter:    84 | Cost: 0.2766520 | Acc train: 1.0000000 | Acc validation: 1.0000000
# Iter:    85 | Cost: 0.2770607 | Acc train: 1.0000000 | Acc validation: 1.0000000
# Iter:    86 | Cost: 0.2795380 | Acc train: 1.0000000 | Acc validation: 1.0000000
# Iter:    87 | Cost: 0.2744677 | Acc train: 1.0000000 | Acc validation: 1.0000000
# Iter:    88 | Cost: 0.2829829 | Acc train: 1.0000000 | Acc validation: 1.0000000
# Iter:    89 | Cost: 0.2815290 | Acc train: 1.0000000 | Acc validation: 1.0000000
# Iter:    90 | Cost: 0.2753089 | Acc train: 1.0000000 | Acc validation: 1.0000000
# Iter:    91 | Cost: 0.2682159 | Acc train: 1.0000000 | Acc validation: 1.0000000
# Iter:    92 | Cost: 0.2667340 | Acc train: 1.0000000 | Acc validation: 1.0000000
# Iter:    93 | Cost: 0.2709024 | Acc train: 1.0000000 | Acc validation: 1.0000000
# Iter:    94 | Cost: 0.2733795 | Acc train: 1.0000000 | Acc validation: 1.0000000
# Iter:    95 | Cost: 0.2691017 | Acc train: 1.0000000 | Acc validation: 1.0000000
# Iter:    96 | Cost: 0.2646007 | Acc train: 1.0000000 | Acc validation: 1.0000000
# Iter:    97 | Cost: 0.2664236 | Acc train: 1.0000000 | Acc validation: 1.0000000
# Iter:    98 | Cost: 0.2697905 | Acc train: 1.0000000 | Acc validation: 1.0000000
# Iter:    99 | Cost: 0.2725476 | Acc train: 1.0000000 | Acc validation: 1.0000000
# Iter:   100 | Cost: 0.2716052 | Acc train: 1.0000000 | Acc validation: 1.0000000

# %%
plt.figure()
cm = plt.cm.RdBu

# make data for decision regions
xx, yy = np.meshgrid(np.linspace(0.0, 1.5, 20), np.linspace(0.0, 1.5, 20))
X_grid = [np.array([x, y]) for x, y in zip(xx.flatten(), yy.flatten())]

# preprocess grid points like data inputs above
padding = 0.3 * np.ones((len(X_grid), 1))
X_grid = np.c_[np.c_[X_grid, padding], np.zeros((len(X_grid), 1))]  # pad each input
normalization = np.sqrt(np.sum(X_grid ** 2, -1))
X_grid = (X_grid.T / normalization).T  # normalize each input
features_grid = np.array(
    [get_angles(x) for x in X_grid]
)  # angles for state preparation are new features
predictions_grid = [variational_classifier(var, angles=f) for f in features_grid]
Z = np.reshape(predictions_grid, xx.shape)

# plot decision regions
cnt = plt.contourf(xx, yy, Z, levels=np.arange(-1, 1.1, 0.1), cmap=cm, alpha=0.8, extend="both")
plt.contour(xx, yy, Z, levels=[0.0], colors=("black",), linestyles=("--",), linewidths=(0.8,))
plt.colorbar(cnt, ticks=[-1, 0, 1])

# plot data
plt.scatter(
    X_train[:, 0][Y_train == 1],
    X_train[:, 1][Y_train == 1],
    c="b",
    marker="o",
    edgecolors="k",
    label="class 1 train",
)
plt.scatter(
    X_val[:, 0][Y_val == 1],
    X_val[:, 1][Y_val == 1],
    c="b",
    marker="^",
    edgecolors="k",
    label="class 1 validation",
)
plt.scatter(
    X_train[:, 0][Y_train == -1],
    X_train[:, 1][Y_train == -1],
    c="r",
    marker="o",
    edgecolors="k",
    label="class -1 train",
)
plt.scatter(
    X_val[:, 0][Y_val == -1],
    X_val[:, 1][Y_val == -1],
    c="r",
    marker="^",
    edgecolors="k",
    label="class -1 validation",
)

plt.legend()
plt.show()
